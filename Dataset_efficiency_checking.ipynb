# %%
import sys
sys.path.append('../')
sys.path.append('.')
#from config import Config

from config import Config
from data_utils import video_to_frames
from data_utils import metadata_loader
from data_utils import dataset_builder
import os
import tensorflow as tf
import matplotlib.pyplot as plt

plt.style.use('ggplot')
# %load_ext autoreload
# %autoreload 2
import time

# %%
# hyperparams
config = Config()

# Decode videos
video_to_frames.decode_videos(config)

# Get metadata
ml = metadata_loader.MetadataLoader(config)
metadata = ml.load_metadata()
# Out:
# Decoding videos to frames.
# ./data/20bn-something-something-v2-video
# Generating training files.
# Deleted folders: 0
# ./data/20bn-something-something-v2-label

# %%
db = dataset_builder.DatasetBuilder(config)
train_dataset = db.make_frame_dataset(metadata['train'])

# %%
start = time.time()
for x, y in train_dataset.batch(85).take(10):
    print(x.shape,y.shape)
    
print("\ntime required for frame dataset:",time.time()-start)

x,y = None, None
# Out:
# (85, 200, 120, 3) (85, 174)
# (85, 200, 120, 3) (85, 174)
# (85, 200, 120, 3) (85, 174)
# (85, 200, 120, 3) (85, 174)
# (85, 200, 120, 3) (85, 174)
# (85, 200, 120, 3) (85, 174)
# (85, 200, 120, 3) (85, 174)
# (85, 200, 120, 3) (85, 174)
# (85, 200, 120, 3) (85, 174)
# (85, 200, 120, 3) (85, 174)
#
# time required for frame dataset: 33.84043741226196

# %%
db2 = dataset_builder.DatasetBuilder(config)
train_dataset2 = db2.make_video_dataset(metadata['train'])

# %%
start = time.time()
for x, y in train_dataset2.batch(1).take(10):
    print(x.shape,y.shape)
print("\ntime required for video dataset:", time.time()-start)
x,y = None, None
# Out:
# (1, 85, 200, 120, 3) (1, 174)
# (1, 85, 200, 120, 3) (1, 174)
# (1, 85, 200, 120, 3) (1, 174)
# (1, 85, 200, 120, 3) (1, 174)
# (1, 85, 200, 120, 3) (1, 174)
# (1, 85, 200, 120, 3) (1, 174)
# (1, 85, 200, 120, 3) (1, 174)
# (1, 85, 200, 120, 3) (1, 174)
# (1, 85, 200, 120, 3) (1, 174)
# (1, 85, 200, 120, 3) (1, 174)
#
# time required for video dataset: 0.9109525680541992

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator()

target_size=(config.img_height,config.img_width)
train_it = datagen.flow_from_directory(config.frame_path,target_size=target_size, class_mode='binary', batch_size=85)
# Out:
# Found 469148 images belonging to 10242 classes.

# %%
nr = 0
start = time.time()
for i in train_it:
    if nr >10: break
    print(i[0].shape)
    nr+=1
print("time required for KERAS frame dataset:", time.time()-start)
# Out:
# (85, 120, 200, 3)
# (85, 120, 200, 3)
# (85, 120, 200, 3)
# (85, 120, 200, 3)
# (85, 120, 200, 3)
# (85, 120, 200, 3)
# (85, 120, 200, 3)
# (85, 120, 200, 3)
# (85, 120, 200, 3)
# (85, 120, 200, 3)
# (85, 120, 200, 3)
# time required for KERAS frame dataset: 1.673015832901001

# %%
metadata['train'][10158.keys()
# Out:
# dict_keys([10158, 1795, 342, 9897, 9073, 5732, 8336, 6520, 909, 6659, 6097, 9396, 2559, 9643, 7470, 4039, 748, 5562, 3283, 1984, 1687, 671, 2705, 408, 7491, 7956, 2907, 1414, 3762, 4254, 4097, 6077, 6322, 8509, 3085, 6002, 8184, 5961, 3720, 2463, 629, 8203, 10242, 2413, 9604, 3477, 2721, 1873, 8346, 5526, 7324, 423, 9712, 4875, 4259, 4325, 6736, 746, 7327, 8212, 3688, 4339, 8539, 2637, 9141, 8182, 3675, 2748, 1110, 8217, 2335, 4837, 9300, 2804, 9885, 10190, 4451, 855, 2482, 7250, 466, 4099, 1920, 4954, 3279, 3854, 359, 3787, 4765, 7155, 5915, 9831, 10060, 3713, 5848, 6094, 328, 5488, 4007, 7190, 6761, 1599, 10123, 1298, 9101, 6165, 4576, 10157, 1180, 2562, 1417, 8675, 5284, 6223, 2511, 2744, 3936, 4217, 9308, 9168, 6614, 9697, 1493, 7062, 7777, 7712, 6003, 2397, 4961, 1245, 5247, 4185, 2603, 8859, 8849, 7399, 199, 6525, 2745, 4101, 9099, 4732, 9818, 4326, 4220, 9565, 655, 2891, 606, 9790, 2351, 8916, 9325, 9936, 6048, 7466, 3901, 5079, 9105, 7416, 772, 6930, 6721, 8553, 4517, 602, 3874, 9385, 3550, 3358, 2431, 7692, 4175, 3556, 8020, 1993, 6946, 9008, 9201, 8622, 3971, 9284, 2404, 8012, 7959, 7605, 9783, 2846, 8476, 4702, 242, 4975, 3652, 131, 9401, 3596, 2539, 4468, 1512, 5296, 4139, 1854, 7378, 6594, 10120, 9419, 7874, 782, 2572, 2926, 3632, 952, 4909, 6509, 3575, 9796, 7787, 5516, 8791, 8296, 7923, 9539, 6122, 7281, 1084, 6588, 5897, 4916, 667, 4105, 8883, 113, 5218, 815, 406, 8032, 2874, 6348, 9686, 4499, 7432, 8704, 4442, 1748, 5161, 8988, 8854, 3351, 2552, 8382, 695, 1302, 5121, 2217, 1766, 8871, 6936, 8769, 10045, 9202, 5623, 2838, 3368, 2120, 8300, 8693, 1837, 3192, 9598, 8116, 8631, 7982, 968, 338, 3611, 2975, 2023, 5515, 1447, 1849, 8107, 5499, 7531, 2084, 784, 9725, 1683, 3441, 1789, 7622, 4484, 845, 9426, 6142, 3983, 2113, 8679, 3154, 575, 8380, 4722, 9313, 3369, 3272, 8606, 1252, 3243, 6349, 8576, 7302, 1814, 7458, 3230, 4556, 2708, 3770, 6012, 3105, 7487, 3969, 7803, 2440, 3379, 2749, 8685, 8291, 8866, 2179, 2950, 9968, 5923, 1652, 7124, 7274, 2579, 2544, 955, 9931, 7149, 5293, 7806, 3773, 7423, 3699, 4776, 9983, 1680, 6224, 4724, 2654, 10078, 2624, 5902, 7365, 8857, 5267, 6769, 5271, 6871, 2606, 2534, 6566, 2578, 5414, 8920, 5701, 8167, 7751, 5018, 6228, 8896, 9458, 5622, 1532, 918, 362, 3890, 8039, 3149, 10228, 1912, 3169, 1616, 3341, 2017, 4844, 3311, 5569, 7828, 2994, 1118, 7082, 3573, 9963, 4213, 1809, 1390, 4346, 1656, 10239, 2918, 8584, 2802, 2855, 4472, 5966, 3624, 9027, 297, 3158, 149, 3816, 5928, 8779, 3536, 7689, 174, 5166, 6124, 3893, 2461, 9564, 168, 3636, 94, 7618, 6991, 1142, 8096, 7128, 7200, 8264, 6326, 6824, 2678, 4225, 7976, 8721, 6511, 6683, 2230, 8268, 586, 346, 5626, 2760, 7317, 6564, 1079, 9887, 2550, 8280, 1312, 9052, 2253, 9834, 3722, 4807, 8328, 9896, 539, 7214, 2925, 307, 4666, 4538, 6133, 9256, 3974, 857, 3206, 7547, 8401, 10050, 9946, 9413, 1824, 3075, 7010, 2330, 8087, 4069, 1662, 139, 2180, 6318, 7246, 3202, 3660, 2535, 8204, 1624, 6304, 8694, 3909, 6131, 7394, 6797, 4935, 6022, 5145, 7312, 9459, 3258, 4851, 5644, 2766, 5025, 1951, 133, 8403, 7326, 7106, 8064, 1670, 577, 419, 3724, 4751, 3561, 201, 1227, 6084, 7974, 9521, 7954, 2011, 7296, 8764, 7881, 8575, 2425, 6218, 8490, 14, 9020, 3604, 2107, 7499, 3048, 3597, 2960, 7464, 1172, 3481, 1909, 4243, 6313, 5567, 8119, 5847, 9460, 7775, 7804, 7104, 8426, 9670, 4744, 7912, 2639, 2061, 9548, 9559, 8945, 4119, 6792, 2276, 1411, 1541, 4872, 7615, 3932, 1192, 6927, 9165, 1372, 9776, 4566, 8519, 1064, 2094, 4153, 6596, 2731, 1074, 8998, 1402, 1186, 5565, 9367, 6347, 6406, 3297, 4979, 5314, 7542, 2378, 175, 6338, 1628, 5084, 874, 9815, 8076, 3205, 2513, 3495, 6828, 403, 1210, 10031, 6184, 3674, 9391, 9838, 8317, 6254, 8155, 4879, 1466, 4271, 3520, 4849, 1777, 10103, 9883, 1097, 8885, 10166, 9213, 2805, 2634, 9292, 7879, 6227, 4798, 41, 5454, 4957, 2965, 8958, 9132, 8021, 1044, 4118, 3587, 10080, 3196, 5221, 6957, 4877, 920, 1538, 1377, 5255, 786, 9055, 4034, 7444, 1436, 2868, 1980, 426, 8973, 7299, 2803, 2575, 3736, 3820, 2451, 1894, 4883, 2 ...
